# %% [markdown]
# # Extra Problems (Metropolis MD)

# %%
using LinearAlgebra
using Plots
using Colors
using Statistics
using Polynomials
using StatsBase
using ProgressBars
gr()
# Out:
# Plots.GRBackend()

# %% [markdown]
# Initial Conditions (NVT)

# %%
l = 30 #box size
Nx = 5 #number of particle columns
Ny = 20 #number of particle rows
rc = 3 #cutoff point where the potential is less than -0.005
Fc = -0.011 #force at the cutoff point
Vc = -0.005 #potential at the cutoff point
dt = 0.0001 #time steps
dt2 = dt^2 #time squared to reduce computing time
T = 100 #temperature
Vmax = sqrt(2 * T) #maximum speed
N = Int(Nx * Ny)
function positionInit()
    X = zeros(N) 
    Y = zeros(N)
    Xborder = [0, l, l, 0, 0]
    Yborder = [0, 0, l, l, 0]
    counter = 1
    for i in 1:Nx
        for j in 1:Ny
        X[counter] = i * (l - 4) / 2 / Nx
        Y[counter] = j * (l - 2) / Ny
        counter += 1
        end 
    end
    return X, Y
end
X, Y = positionInit()
scatter(X, Y, title = "Initial positions", dpi = 500, background = :black, legend = false, aspectratio = 1, markersize = 2, xlims = (0, l), ylims = (0, l))

# %% [markdown]
# Potential Energy Change function

# %%
function potentialChange(X, Y)
    
end
